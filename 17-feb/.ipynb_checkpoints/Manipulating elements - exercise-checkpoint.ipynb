# %%
import pandas as pd

# %%
cars = pd.read_csv('cars.csv')

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# Create a subset of the DataFrame cars with all cars having an mpg higher than 40! Save the subset in the variable high_eff!
# high_eff should be a new and independent DataFrame. Any changes in high_eff shall not influence the original DataFrame cars

# %%
high_eff = cars.loc[cars.mpg > 40]

# %%
high_eff
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 244  43.1          4          90.0        48.0    1985          21.5
# 309  41.5          4          98.0        76.0    2144          14.7
# 322  46.6          4          86.0        65.0    2110          17.9
# 324  40.8          4          85.0        65.0    2110          19.2
# 325  44.3          4          90.0        48.0    2085          21.7
# 326  43.4          4          90.0        48.0    2335          23.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 330  40.9          4          85.0         NaN    1835          17.3
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                     name
# 244          78  europe  vw rabbit custom diesel
# 309          80  europe                vw rabbit
# 322          80   japan                mazda glc
# 324          80   japan               datsun 210
# ...

# %% [markdown]
# Cap the mpg for all cars in high_eff to 40 (Overwrite the mpg values)

# %%
high_eff.loc[:,'mpg'] = 40

# %%
high_eff
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 244   40          4          90.0        48.0    1985          21.5
# 309   40          4          98.0        76.0    2144          14.7
# 322   40          4          86.0        65.0    2110          17.9
# 324   40          4          85.0        65.0    2110          19.2
# 325   40          4          90.0        48.0    2085          21.7
# 326   40          4          90.0        48.0    2335          23.7
# 329   40          4          91.0        67.0    1850          13.8
# 330   40          4          85.0         NaN    1835          17.3
# 394   40          4          97.0        52.0    2130          24.6
# mpg   40         40          40.0        40.0      40          40.0
#
#      model_year  origin                     name
# 244          78  europe  vw rabbit custom diesel
# 309          80  europe                vw rabbit
# 322          80   japan                mazda glc
# ...

# %% [markdown]
# Check in the original cars Dataframe, whether where are still values greater than 40 in the "mpg" column

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.mpg.max()
# Out:
# 46.6

# %% [markdown]
# Now, we want to manipulate the original DataFrame cars. Cap all mpg values greater than 40 to 40

# %%
cars.loc[cars.mpg > 40] = 40

# %%
cars.mpg.max()
# Out:
# 40.0
